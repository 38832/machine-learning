# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("titanic.csv")
df.head()
# Out:
#    PassengerId                                               Name  Pclass  \
# 0            1                            Braund, Mr. Owen Harris       3
# 1            2  Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 2            3                             Heikkinen, Miss. Laina       3
# 3            4       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 4            5                           Allen, Mr. William Henry       3
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S
#
#    Survived
# 0         0
# 1         1
# 2         1
# 3         1
# 4         0

# %%
df.drop(['PassengerId','Name','SibSp','Parch','Ticket','Cabin','Embarked'],axis='columns',inplace=True)
df.head()
# Out:
#    Pclass     Sex   Age     Fare  Survived
# 0       3    male  22.0   7.2500         0
# 1       1  female  38.0  71.2833         1
# 2       3  female  26.0   7.9250         1
# 3       1  female  35.0  53.1000         1
# 4       3    male  35.0   8.0500         0

# %%
target = df.Survived
input = df.drop(['Survived'], axis='columns')
input.head()
# Out:
#    Pclass     Sex   Age     Fare
# 0       3    male  22.0   7.2500
# 1       1  female  38.0  71.2833
# 2       3  female  26.0   7.9250
# 3       1  female  35.0  53.1000
# 4       3    male  35.0   8.0500

# %%
dummies = pd.get_dummies(input.Sex)
dummies.head(3)
# Out:
#    female   male
# 0   False   True
# 1    True  False
# 2    True  False

# %%
input = pd.concat([input, dummies], axis='columns')
input
# Out:
#      Pclass     Sex   Age     Fare  female   male
# 0         3    male  22.0   7.2500   False   True
# 1         1  female  38.0  71.2833    True  False
# 2         3  female  26.0   7.9250    True  False
# 3         1  female  35.0  53.1000    True  False
# 4         3    male  35.0   8.0500   False   True
# ..      ...     ...   ...      ...     ...    ...
# 886       2    male  27.0  13.0000   False   True
# 887       1  female  19.0  30.0000    True  False
# 888       3  female   NaN  23.4500    True  False
# 889       1    male  26.0  30.0000   False   True
# 890       3    male  32.0   7.7500   False   True
#
# [891 rows x 6 columns]

# %%
input.drop('Sex', axis='columns', inplace = True)
input.head()
# Out:
#    Pclass   Age     Fare  female   male
# 0       3  22.0   7.2500   False   True
# 1       1  38.0  71.2833    True  False
# 2       3  26.0   7.9250    True  False
# 3       1  35.0  53.1000    True  False
# 4       3  35.0   8.0500   False   True

# %%
input.columns[input.isna().any()]
# Out:
# Index(['Age'], dtype='object')

# %%
input.describe()
# Out:
#            Pclass         Age        Fare
# count  891.000000  714.000000  891.000000
# mean     2.308642   29.699118   32.204208
# std      0.836071   14.526497   49.693429
# min      1.000000    0.420000    0.000000
# 25%      2.000000   20.125000    7.910400
# 50%      3.000000   28.000000   14.454200
# 75%      3.000000   38.000000   31.000000
# max      3.000000   80.000000  512.329200

# %%
input.Age = input.Age.fillna(input.Age.mean())
input.head()
# Out:
#    Pclass   Age     Fare  female   male
# 0       3  22.0   7.2500   False   True
# 1       1  38.0  71.2833    True  False
# 2       3  26.0   7.9250    True  False
# 3       1  35.0  53.1000    True  False
# 4       3  35.0   8.0500   False   True

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(input, target, test_size=0.2)

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()

# %%
model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
model.score(X_test, y_test)
# Out:
# 0.7653631284916201

# %%
X_test[:10]
# Out:
#      Pclass   Age      Fare  female   male
# 389       2  17.0   12.0000    True  False
# 103       3  33.0    8.6542   False   True
# 380       1  42.0  227.5250    True  False
# 570       2  62.0   10.5000   False   True
# 269       1  35.0  135.6333    True  False
# 114       3  17.0   14.4583    True  False
# 118       1  24.0  247.5208   False   True
# 349       3  42.0    8.6625   False   True
# 784       3  25.0    7.0500   False   True
# 576       2  34.0   13.0000    True  False

# %%
y_test[:10]
# Out:
# 389    1
# 103    0
# 380    1
# 570    1
# 269    1
# 114    0
# 118    0
# 349    0
# 784    0
# 576    1
# Name: Survived, dtype: int64

# %%
model.predict_proba(X_test[:10])
# Out:
# array([[4.15344482e-02, 9.58465552e-01],
#        [9.92856092e-01, 7.14390768e-03],
#        [4.51277599e-11, 1.00000000e+00],
#        [9.73544746e-01, 2.64552542e-02],
#        [2.10851250e-05, 9.99978915e-01],
#        [9.43330537e-02, 9.05666946e-01],
#        [1.25004343e-09, 9.99999999e-01],
#        [9.92504878e-01, 7.49512177e-03],
#        [9.92596861e-01, 7.40313879e-03],
#        [4.67088141e-02, 9.53291186e-01]])
